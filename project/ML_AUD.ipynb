# %%
import numpy as np
import pandas as pd
import configparser

dataconfig = configparser.ConfigParser()
dataconfig.read('config.ini', encoding='UTF-8')

data = pd.read_csv(dataconfig['DEFAULT']['data_path'])
data

# %%
# Out:
#      Unnamed: 0  num  puretone_aur_00125m  puretone_aur_00250m  \
# 0             0    1                  NaN                 10.0
# 1             1    2                  NaN                 -5.0
# 2             2    3                  NaN                 35.0
# 3             3    4                  NaN                 10.0
# 4             4    5                  NaN                 25.0
# ..          ...  ...                  ...                  ...
# 495         495  496                  NaN                 25.0
# 496         496  497                  NaN                 30.0
# 497         497  498                  NaN                 20.0
# 498         498  499                  NaN                 20.0
# 499         499  500                  NaN                  0.0
#
#      puretone_aur_00500m  puretone_aur_00750m  puretone_aur_01000m  \
# 0                     35                  NaN                   50
# 1                     10                  NaN                    0
# ...
